# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import pytorch_lightning as pl
from torchmetrics.classification import MulticlassAccuracy
from torch_geometric.nn import GCNConv, TopKPooling, global_mean_pool, global_max_pool, GATv2Conv
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader
from sklearn.metrics import f1_score
import tensorflow as tf

# %%
mediapipe_edges = [
    (0, 1), (0, 2), (1, 3), (2, 4), (3, 5), (4, 6), (5, 7), (6, 8),
    (9, 10), (11, 12), (11, 13), (13, 15), (15, 17), (15, 19), (15, 21),
    (12, 14), (14, 16), (16, 18), (16, 20), (16, 22), (11, 23), (12, 24),
    (23, 24), (23, 25), (25, 27), (27, 29), (29, 31), (24, 26), (26, 28),
    (28, 30), (30, 32), (0, 11), (0, 12)
]

# %%
class HGCN(nn.Module):
    def __init__(self, in_channels, hidden_channels, num_classes):
        super(HGCN, self).__init__()

        self.conv1 = GCNConv(in_channels, hidden_channels)
        self.conv1b = GCNConv(hidden_channels, hidden_channels)
        self.bn1 = nn.BatchNorm1d(hidden_channels)
        self.pool1 = TopKPooling(hidden_channels, ratio=0.8)

        self.conv2 = GCNConv(hidden_channels, hidden_channels)
        self.conv2b = GCNConv(hidden_channels, hidden_channels)
        self.bn2 = nn.BatchNorm1d(hidden_channels)
        self.pool2 = TopKPooling(hidden_channels, ratio=0.6)
        

        self.lin1 = nn.Linear(hidden_channels * 2, hidden_channels)
        self.lin2 = nn.Linear(hidden_channels, hidden_channels//2)
        self.lin3 = nn.Linear(hidden_channels//2, num_classes)

    def forward(self, data):
        x, edge_index, batch = data.x, data.edge_index, data.batch
        x = F.relu(self.conv1(x, edge_index))
        x = F.relu(self.conv1b(x, edge_index))
        x = self.bn1(x)
        x, edge_index, _, batch, _,_ = self.pool1(x, edge_index, None, batch)
        x = F.relu(self.conv2(x, edge_index))
        x = F.relu(self.conv2b(x, edge_index))
        x = self.bn2(x)
        x, edge_index, _, batch, _,_ = self.pool2(x, edge_index, None, batch)
        x = torch.cat([global_mean_pool(x, batch), global_max_pool(x, batch)], dim=1)
        
        x = F.relu(self.lin1(x))
        x = F.relu(self.lin2(x))
        x = self.lin3(x)
        return F.log_softmax(x, dim=1)

# %%
class ImprovedHGCN(nn.Module):
    def __init__(self, in_channels, hidden_channels, num_classes):
        super(ImprovedHGCN, self).__init__()
        
        # GCN Block 1
        self.conv1 = GCNConv(in_channels, hidden_channels)
        self.conv1b = GCNConv(hidden_channels, hidden_channels)
        self.bn1b = nn.BatchNorm1d(hidden_channels)
        self.conv1c = GCNConv(hidden_channels, hidden_channels)
        self.bn1c = nn.BatchNorm1d(hidden_channels)
        self.pool1 = TopKPooling(hidden_channels, ratio=0.9)
        self.res1 = nn.Linear(in_channels, hidden_channels)
        
        # GCN Block 2
        self.conv2 = GCNConv(hidden_channels, hidden_channels)
        self.bn2 = nn.BatchNorm1d(hidden_channels)
        self.conv2b = GCNConv(hidden_channels, hidden_channels)
        self.bn2b = nn.BatchNorm1d(hidden_channels)
        self.conv2c = GCNConv(hidden_channels, hidden_channels)
        self.bn2c = nn.BatchNorm1d(hidden_channels)
        self.pool2 = TopKPooling(hidden_channels, ratio=0.9)
        self.res2 = nn.Linear(hidden_channels, hidden_channels)
        
        # GCN Block 3
        self.conv3 = GCNConv(hidden_channels, hidden_channels)
        self.bn3 = nn.BatchNorm1d(hidden_channels)
        self.conv3b = GCNConv(hidden_channels, hidden_channels)
        self.bn3b = nn.BatchNorm1d(hidden_channels)
        self.conv3c = GCNConv(hidden_channels, hidden_channels)
        self.bn3c = nn.BatchNorm1d(hidden_channels)
        self.pool3 = TopKPooling(hidden_channels, ratio=0.8)
        self.res3 = nn.Linear(hidden_channels, hidden_channels)
        
        # GCN Block 4
        self.conv4 = GCNConv(hidden_channels, hidden_channels)
        self.bn4 = nn.BatchNorm1d(hidden_channels)
        self.conv4b = GCNConv(hidden_channels, hidden_channels)
        self.bn4b = nn.BatchNorm1d(hidden_channels)
        self.conv4c = GCNConv(hidden_channels, hidden_channels)
        self.bn4c = nn.BatchNorm1d(hidden_channels)
        self.pool4 = TopKPooling(hidden_channels, ratio=0.8)
        self.res4 = nn.Linear(hidden_channels, hidden_channels)

        # Final classifier
        self.lin1 = nn.Linear(hidden_channels * 2 * 4, hidden_channels)  # 4 stages × (mean + max)
        self.lin2 = nn.Linear(hidden_channels, hidden_channels // 2)
        self.lin3 = nn.Linear(hidden_channels // 2, num_classes)

    def gcn_block(self, x, edge_index, convs, bns, res_layer, pool, batch):
        # Residual projection
        res = res_layer(x)
        
        # 3-layer GCN with BN
        x = F.relu(bns[0](convs[0](x, edge_index)) + res)
        x = F.relu(bns[1](convs[1](x, edge_index)))
        x = F.relu(bns[2](convs[2](x, edge_index)))
        
        # Pooling
        x, edge_index, _, batch, _, _ = pool(x, edge_index, batch=batch)
        return x, edge_index, batch

    def forward(self, data):
        x, edge_index, batch = data.x, data.edge_index, data.batch
        multi_scale_features = []

        # GCN Block 1
        x, edge_index, batch = self.gcn_block(
            x, edge_index,
            [self.conv1, self.conv1b, self.conv1c],
            [self.bn1, self.bn1b, self.bn1c],
            self.res1, self.pool1, batch)
        multi_scale_features.append(torch.cat([global_mean_pool(x, batch), global_max_pool(x, batch)], dim=1))
        
        # GCN Block 2
        x, edge_index, batch = self.gcn_block(
            x, edge_index,
            [self.conv2, self.conv2b, self.conv2c],
            [self.bn2, self.bn2b, self.bn2c],
            self.res2, self.pool2, batch)
        multi_scale_features.append(torch.cat([global_mean_pool(x, batch), global_max_pool(x, batch)], dim=1))
        
        # GCN Block 3
        x, edge_index, batch = self.gcn_block(
            x, edge_index,
            [self.conv3, self.conv3b, self.conv3c],
            [self.bn3, self.bn3b, self.bn3c],
            self.res3, self.pool3, batch)
        multi_scale_features.append(torch.cat([global_mean_pool(x, batch), global_max_pool(x, batch)], dim=1))

        # GCN Block 4
        x, edge_index, batch = self.gcn_block(
            x, edge_index,
            [self.conv4, self.conv4b, self.conv4c],
            [self.bn4, self.bn4b, self.bn4c],
            self.res4, self.pool4, batch)
        multi_scale_features.append(torch.cat([global_mean_pool(x, batch), global_max_pool(x, batch)], dim=1))

        # Multi-scale feature fusion
        x = torch.cat(multi_scale_features, dim=1)
        x = F.relu(self.lin1(x))
        x = F.relu(self.lin2(x))
        x = self.lin3(x)
        return F.log_softmax(x, dim=1)

# %% [markdown]
# Run for LE21

# %%
# Load the dataset
import pickle
train_file = r"C:\Users\johna\Desktop\CS3264proj\train_falls_le2.pkl"
test_file = r"C:\Users\johna\Desktop\CS3264proj\test_falls_le2.pkl"
with open(train_file, 'rb') as f:
    dataset = pickle.load(f)
print(f"Loaded dataset size: {len(dataset)}")
with open(test_file, 'rb') as f:
    test_dataset = pickle.load(f)
print(f"Loaded test dataset size: {len(test_dataset)}")

def build_graph(sequence_tensor, label):
    """
    sequence_tensor: Tensor of shape (T, 33, 4)
    label: int (class label for the whole sequence)
    """
    T, J, F = sequence_tensor.shape  # Time, Joints, Features
    x = sequence_tensor.reshape(T * J, F)  # (T*33, 4)


    edge_list = []

    # Intra-frame edges
    for t in range(T):
        for u, v in mediapipe_edges:
            edge_list += [(t * J + u, t * J + v), (t * J + v, t * J + u)]

    # Inter-frame (temporal) self-links
    for t in range(T - 1):
        for j in range(J):
            edge_list += [(t * J + j, (t + 1) * J + j), ((t + 1) * J + j, t * J + j)]

    edge_index = torch.tensor(edge_list, dtype=torch.long).t().contiguous()
    data = Data(x=x, edge_index=edge_index, y=torch.tensor(label, dtype=torch.long))
    # data = Data(x=x, edge_index=edge_index, y=label)
    print(f"Data object: {data}")
    # print(f"Data x shape: {data.x.shape}")
    # print(f"Data edge_index shape: {data.edge_index.shape}")
    # print(f"Data y shape: {data.y}")
    # print(f"Data num_nodes: {data.num_nodes}")
    return data
graphs = []
for sequence_tensor, label in dataset:
    # Convert TensorFlow tensor to NumPy, then to PyTorch tensor
    sequence_tensor = torch.tensor(sequence_tensor.numpy())  # Convert to PyTorch tensor
    sequence_tensor = sequence_tensor.permute(1,2,0)  # Change shape to (T, 4, 33)
    graph = build_graph(sequence_tensor, label)
    graphs.append(graph)

test_graphs = []
for sequence_tensor, label in test_dataset:
    sequence_tensor = torch.tensor(sequence_tensor.numpy())  # Convert to PyTorch tensor
    sequence_tensor = sequence_tensor.permute(1,2,0)  # Change shape to (T, 4, 33)
    graph = build_graph(sequence_tensor, label)
    test_graphs.append(graph)
# Out:
# Loaded dataset size: 152
# Loaded test dataset size: 38
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)

# %%
model = HGCN(in_channels=4, hidden_channels=64, num_classes=2)
# model = ImprovedHGCN(in_channels=4, hidden_channels=64, num_classes=2)
train_loader = DataLoader(graphs, batch_size=16, shuffle=True) #batch default is 32

test_loader = DataLoader(test_graphs, batch_size=16, shuffle=False)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=0.001, weight_decay=0.01) #try sgd or adam, or adamw
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=15, gamma=0.1) 
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)
# Training loop
epochs = 50 # May need more epochs for the combined model to train
overall_acc = 0.0
overall_loss = 0.0

for epoch in range(epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    for i, batch in enumerate(train_loader):
        batch_data = batch.to(device)  # Move the entire batch to the device
        batch_labels = batch.y.to(device)  # Extract labels
        optimizer.zero_grad()
        outputs = model(batch_data)
        loss = criterion(outputs, batch_labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += batch_labels.size(0)
        correct += (predicted == batch_labels).sum().item()

        loss_per_epoch = running_loss / len(train_loader)
        epoch_acc = 100 * correct / total
        print(f"Epoch [{epoch+1}/{epochs}], Step [{i+1}/{len(train_loader)}], Loss: {loss_per_epoch:.4f}, Accuracy: {epoch_acc:.2f}%")
        
    
    model.eval()
    with torch.no_grad():
        val_loss = 0.0
        correct = 0
        total = 0
        all_preds = []
        all_labels = []
        for i, batch_test_data in enumerate(test_loader):
            batch_test_data = batch_test_data.to(device)  # Move the entire batch to the device
            batch_test_labels = batch_test_data.y.to(device)  # Extract labels
            optimizer.zero_grad()
            # Forward pass

            outputs = model(batch_test_data)
            loss = criterion(outputs, batch_test_labels)

            val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += batch_test_labels.size(0)
            correct += (predicted == batch_test_labels).sum().item()
            
            all_preds.append(predicted.cpu())
            all_labels.append(batch_test_labels.cpu())


        val_loss /= len(test_loader)
        val_acc = 100 * correct / total
        
        all_preds = torch.cat(all_preds)
        all_labels = torch.cat(all_labels)

        val_f1 = f1_score(all_labels.cpu(), all_preds.cpu(), average='weighted')

        print(f"Epoch [{epoch+1}/{epochs}], Val Loss: {val_loss:.4f}, Val Accuracy: {val_acc:.2f}%, Val F1 Score: {val_f1:.4f}")

        # Save model if it's the best so far
        if val_loss < overall_loss or val_acc > overall_acc:
            overall_acc = val_acc
            overall_loss = val_loss
            # torch.save(model.state_dict(), 'best_stgcn_reasoning_model.pth')
            print(f"Saved new best model with Val Accuracy: {overall_acc:.2f}% and F1 Score: {val_f1:.4f}")

    scheduler.step() # Step the scheduler after validation

print("Training completed.")
print(f"Best Val Accuracy achieved: {overall_acc:.2f}%")
print(f"Best Val Loss achieved: {overall_loss:.4f}")
# Out:
# Epoch [1/50], Step [1/10], Loss: 0.0739, Accuracy: 43.75%
# Epoch [1/50], Step [2/10], Loss: 0.1467, Accuracy: 40.62%
# Epoch [1/50], Step [3/10], Loss: 0.2137, Accuracy: 45.83%
# Epoch [1/50], Step [4/10], Loss: 0.2734, Accuracy: 53.12%
# Epoch [1/50], Step [5/10], Loss: 0.3297, Accuracy: 58.75%
# Epoch [1/50], Step [6/10], Loss: 0.3772, Accuracy: 63.54%
# Epoch [1/50], Step [7/10], Loss: 0.4376, Accuracy: 65.18%
# Epoch [1/50], Step [8/10], Loss: 0.4830, Accuracy: 66.41%
# Epoch [1/50], Step [9/10], Loss: 0.5424, Accuracy: 67.36%
# Epoch [1/50], Step [10/10], Loss: 0.6086, Accuracy: 68.42%
# Epoch [1/50], Val Loss: 0.7354, Val Accuracy: 31.58%, Val F1 Score: 0.1516
# Saved new best model with Val Accuracy: 31.58% and F1 Score: 0.1516
# Epoch [2/50], Step [1/10], Loss: 0.0601, Accuracy: 68.75%
# Epoch [2/50], Step [2/10], Loss: 0.1031, Accuracy: 81.25%
# Epoch [2/50], Step [3/10], Loss: 0.1334, Accuracy: 83.33%
# Epoch [2/50], Step [4/10], Loss: 0.2011, Accuracy: 78.12%
# Epoch [2/50], Step [5/10], Loss: 0.2458, Accuracy: 77.50%
# Epoch [2/50], Step [6/10], Loss: 0.2986, Accuracy: 78.12%
# Epoch [2/50], Step [7/10], Loss: 0.3343, Accuracy: 78.57%
# Epoch [2/50], Step [8/10], Loss: 0.3766, Accuracy: 79.69%
# Epoch [2/50], Step [9/10], Loss: 0.4045, Accuracy: 81.94%
# Epoch [2/50], Step [10/10], Loss: 0.4369, Accuracy: 82.89%
# Epoch [2/50], Val Loss: 0.7410, Val Accuracy: 31.58%, Val F1 Score: 0.1516
# Epoch [3/50], Step [1/10], Loss: 0.0238, Accuracy: 93.75%
# Epoch [3/50], Step [2/10], Loss: 0.0391, Accuracy: 96.88%
# Epoch [3/50], Step [3/10], Loss: 0.0724, Accuracy: 93.75%
# Epoch [3/50], Step [4/10], Loss: 0.1121, Accuracy: 92.19%
# Epoch [3/50], Step [5/10], Loss: 0.1696, Accuracy: 86.25%
# Epoch [3/50], Step [6/10], Loss: 0.2083, Accuracy: 86.46%
Val Accuracy: 94.74%, Val F1 Score: 0.9460
# Epoch [37/50], Step [1/10], Loss: 0.0006, Accuracy: 100.00%
# Epoch [37/50], Step [2/10], Loss: 0.0029, Accuracy: 100.00%
# Epoch [37/50], Step [3/10], Loss: 0.0047, Accuracy: 100.00%
# Epoch [37/50], Step [4/10], Loss: 0.0054, Accuracy: 100.00%
# Epoch [37/50], Step [5/10], Loss: 0.0061, Accuracy: 100.00%
# Epoch [37/50], Step [6/10], Loss: 0.0094, Accuracy: 100.00%
# Epoch [37/50], Step [7/10], Loss: 0.0103, Accuracy: 100.00%
# Epoch [37/50], Step [8/10], Loss: 0.0106, Accuracy: 100.00%
# Epoch [37/50], Step [9/10], Loss: 0.0114, Accuracy: 100.00%
# Epoch [37/50], Step [10/10], Loss: 0.0116, Accuracy: 100.00%
# Epoch [37/50], Val Loss: 0.1063, Val Accuracy: 94.74%, Val F1 Score: 0.9460
# Epoch [38/50], Step [1/10], Loss: 0.0006, Accuracy: 100.00%
# Epoch [38/50], Step [2/10], Loss: 0.0008, Accuracy: 100.00%
# Epoch [38/50], Step [3/10], Loss: 0.0011, Accuracy: 100.00%
# Epoch [38/50], Step [4/10], Loss: 0.0021, Accuracy: 100.00%
# Epoch [38/50], Step [5/10], Loss: 0.0037, Accuracy: 100.00%
# Epoch [38/50], Step [6/10], Loss: 0.0043, Accuracy: 100.00%
# Epoch [38/50], Step [7/10], Loss: 0.0052, Accuracy: 100.00%
# Epoch [38/50], Step [8/10], Loss: 0.0059, Accuracy: 100.00%
# Epoch [38/50], Step [9/10], Loss: 0.0062, Accuracy: 100.00%
# Epoch [38/50], Step [10/10], Loss: 0.0104, Accuracy: 100.00%
# Epoch [38/50], Val Loss: 0.1031, Val Accuracy: 94.74%, Val F1 Score: 0.9460
# Epoch [39/50], Step [1/10], Loss: 0.0008, Accuracy: 100.00%
# Epoch [39/50], Step [2/10], Loss: 0.0013, Accuracy: 100.00%
# Epoch [39/50], Step [3/10], Loss: 0.0015, Accuracy: 100.00%
# Epoch [39/50], Step [4/10], Loss: 0.0017, Accuracy: 100.00%
# Epoch [39/50], Step [5/10], Loss: 0.0038, Accuracy: 100.00%
# Epoch [39/50], Step [6/10], Loss: 0.0044, Accuracy: 100.00%
# Epoch [39/50], Step [7/10], Loss: 0.0053, Accuracy: 100.00%
# Epoch [39/50], Step [8/10], Loss: 0.0076, Accuracy: 100.00%
# Epoch [39/50], Step [9/10], Loss: 0.0080, Accuracy: 100.00%
# Epoch [39/50], Step [10/10], Loss: 0.0088, Accuracy: 100.00%
# Epoch [39/50], Val Loss: 0.1032, Val Accuracy: 94.74%, Val F1 Score: 0.9460
# Epoch [40/50], Step [1/10], Loss: 0.0006, Accuracy: 100.00%
# Epoch [40/50], Step [2/10], Loss: 0.0017, Accuracy: 100.00%
# Epoch [40/50], Step [3/10], Loss: 0.0041, Accuracy: 100.00%
# Epoch [40/50], Step [4/10], Loss: 0.0043, Accuracy: 100.00%
# Epoch [40/50], Step [5/10], Loss: 0.0063, Accuracy: 100.00%
# Epoch [40/50], Step [6/10], Loss: 0.0064, Accuracy: 100.00%
# Epoch [40/50], Step [7/10], Loss: 0.0081, Accuracy: 100.00%
# Epoch [40/50], Step [8/10], Loss: 0.0096, Accuracy: 100.00%
# Epoch [40/50], Step [9/10], Loss: 0.0103, Accuracy: 100.00%
# Epoch [40/50], Step [10/10], Loss: 0.0106, Accuracy: 100.00%
# Epoch [40/50], Val Loss: 0.0902, Val Accuracy: 94.74%, Val F1 Score: 0.9460
# Epoch
Val Accuracy: 94.74%, Val F1 Score: 0.9460
# Epoch [45/50], Step [1/10], Loss: 0.0006, Accuracy: 100.00%
# Epoch [45/50], Step [2/10], Loss: 0.0026, Accuracy: 100.00%
# Epoch [45/50], Step [3/10], Loss: 0.0036, Accuracy: 100.00%
# Epoch [45/50], Step [4/10], Loss: 0.0040, Accuracy: 100.00%
# Epoch [45/50], Step [5/10], Loss: 0.0125, Accuracy: 98.75%
# Epoch [45/50], Step [6/10], Loss: 0.0153, Accuracy: 98.96%
# Epoch [45/50], Step [7/10], Loss: 0.0155, Accuracy: 99.11%
# Epoch [45/50], Step [8/10], Loss: 0.0156, Accuracy: 99.22%
# Epoch [45/50], Step [9/10], Loss: 0.0159, Accuracy: 99.31%
# Epoch [45/50], Step [10/10], Loss: 0.0168, Accuracy: 99.34%
# Epoch [45/50], Val Loss: 0.0856, Val Accuracy: 94.74%, Val F1 Score: 0.9460
# Epoch [46/50], Step [1/10], Loss: 0.0020, Accuracy: 100.00%
# Epoch [46/50], Step [2/10], Loss: 0.0022, Accuracy: 100.00%
# Epoch [46/50], Step [3/10], Loss: 0.0024, Accuracy: 100.00%
# Epoch [46/50], Step [4/10], Loss: 0.0026, Accuracy: 100.00%
# Epoch [46/50], Step [5/10], Loss: 0.0038, Accuracy: 100.00%
# Epoch [46/50], Step [6/10], Loss: 0.0048, Accuracy: 100.00%
# Epoch [46/50], Step [7/10], Loss: 0.0061, Accuracy: 100.00%
# Epoch [46/50], Step [8/10], Loss: 0.0066, Accuracy: 100.00%
# Epoch [46/50], Step [9/10], Loss: 0.0086, Accuracy: 100.00%
# Epoch [46/50], Step [10/10], Loss: 0.0219, Accuracy: 99.34%
# Epoch [46/50], Val Loss: 0.0940, Val Accuracy: 94.74%, Val F1 Score: 0.9460
# Epoch [47/50], Step [1/10], Loss: 0.0004, Accuracy: 100.00%
# Epoch [47/50], Step [2/10], Loss: 0.0015, Accuracy: 100.00%
# Epoch [47/50], Step [3/10], Loss: 0.0028, Accuracy: 100.00%
# Epoch [47/50], Step [4/10], Loss: 0.0031, Accuracy: 100.00%
# Epoch [47/50], Step [5/10], Loss: 0.0040, Accuracy: 100.00%
# Epoch [47/50], Step [6/10], Loss: 0.0043, Accuracy: 100.00%
# Epoch [47/50], Step [7/10], Loss: 0.0058, Accuracy: 100.00%
# Epoch [47/50], Step [8/10], Loss: 0.0062, Accuracy: 100.00%
# Epoch [47/50], Step [9/10], Loss: 0.0081, Accuracy: 100.00%
# Epoch [47/50], Step [10/10], Loss: 0.0109, Accuracy: 100.00%
# Epoch [47/50], Val Loss: 0.0971, Val Accuracy: 94.74%, Val F1 Score: 0.9460
# Epoch [48/50], Step [1/10], Loss: 0.0008, Accuracy: 100.00%
# Epoch [48/50], Step [2/10], Loss: 0.0012, Accuracy: 100.00%
# Epoch [48/50], Step [3/10], Loss: 0.0023, Accuracy: 100.00%
# Epoch [48/50], Step [4/10], Loss: 0.0042, Accuracy: 100.00%
# Epoch [48/50], Step [5/10], Loss: 0.0103, Accuracy: 98.75%
# Epoch [48/50], Step [6/10], Loss: 0.0113, Accuracy: 98.96%
# Epoch [48/50], Step [7/10], Loss: 0.0117, Accuracy: 99.11%
# Epoch [48/50], Step [8/10], Loss: 0.0167, Accuracy: 98.44%
# Epoch [48/50], Step [9/10], Loss: 0.0169, Accuracy: 98.61%
# Epoch [48/50], Step [10/10], Loss: 0.0178, Accuracy: 98.68%
# Epoch [48/50], Val Loss: 0.0853, Val Accuracy: 97.37%, Val F1 Score: 0.9734
# Epoch [49/50], Step [1/10], Loss: 0.0006, Accuracy: 100.00%
# Epoch [49/50], Step [2/10], Loss: 0.0015, Accuracy: 100.00%
# Epoch [49/50], Step [3/10], Loss: 0.0019, Accuracy: 100.00%
# Epoch [49/50], Step [4/10], Loss: 0.0039, Accuracy: 100.00%
# Epoch [49/50], Step [5/10], Loss: 0.0047, Accuracy: 100.00%
# Epoch [49/50], Step [6/10], Loss: 0.0050, Accuracy: 100.00%
# Epoch [49/50], Step [7/10], Loss: 0.0054, Accuracy: 100.00%
# Epoch [49/50], Step [8/10], Loss: 0.0061, Accuracy: 100.00%
# Epoch [49/50], Step [9/10], Loss: 0.0069, Accuracy: 100.00%
# Epoch [49/50], Step [10/10], Loss: 0.0073, Accuracy: 100.00%
# Epoch [49/50], Val Loss: 0.0802, Val Accuracy: 97.37%, Val F1 Score: 0.9734
# Epoch [50/50], Step [1/10], Loss: 0.0007, Accuracy: 100.00%
# Epoch [50/50], Step [2/10], Loss: 0.0023, Accuracy: 100.00%
# Epoch [50/50], Step [3/10], Loss: 0.0024, Accuracy: 100.00%
# Epoch [50/50], Step [4/10], Loss: 0.0024, Accuracy: 100.00%
# Epoch [50/50], Step [5/10], Loss: 0.0032, Accuracy: 100.00%
# Epoch [50/50], Step [6/10], Loss: 0.0040, Accuracy: 100.00%
# Epoch [50/50], Step [7/10], Loss: 0.0048, Accuracy: 100.00%
# Epoch [50/50], Step [8/10], Loss: 0.0055, Accuracy: 100.00%
# Epoch [50/50], Step [9/10], Loss: 0.0064, Accuracy: 100.00%
# Epoch [50/50], Step [10/10], Loss: 0.0127, Accuracy: 100.00%
# Epoch [50/50], Val Loss: 0.1042, Val Accuracy: 94.74%, Val F1 Score: 0.9460
# Training completed.
# Best Val Accuracy achieved: 100.00%
# Best Val Loss achieved: 0.0190

# %%
import pickle
file = r"C:\Users\johna\Desktop\CS3264proj\pose_dataset.pkl"
with open(file, 'rb') as f:
    dataset = pickle.load(f)
print(f"Loaded dataset size: {len(dataset)}")
print(dataset[0][1])
# Out:
# Loaded dataset size: 190
# 1

# %% [markdown]
# Run for URfall

# %%
import pickle
import pickletools
train_file = r"C:\Users\johna\Desktop\CS3264proj\train_ur_fall_50_frames_4_features.pkl"
val_file = r'C:\Users\johna\Desktop\CS3264proj\val_ur_fall_50_frames_4_features.pkl'  

with open('train_ur_fall_50_frames_4_features.pkl', 'rb') as f:
    dataset = pickle.load(f)
print(f"Loaded dataset size: {len(dataset)}")
with open('val_ur_fall_50_frames_4_features.pkl', 'rb') as f:
    test_dataset = pickle.load(f)
print(f"Loaded test dataset size: {len(test_dataset)}")

def build_graph(sequence_tensor, label):
    """
    sequence_tensor: Tensor of shape (T, 33, 4)
    label: int (class label for the whole sequence)
    """
    T, J, F = sequence_tensor.shape  # Time, Joints, Features
    x = sequence_tensor.reshape(T * J, F)  # (T*33, 4)


    edge_list = []

    # Intra-frame edges
    for t in range(T):
        for u, v in mediapipe_edges:
            edge_list += [(t * J + u, t * J + v), (t * J + v, t * J + u)]

    # Inter-frame (temporal) self-links
    for t in range(T - 1):
        for j in range(J):
            edge_list += [(t * J + j, (t + 1) * J + j), ((t + 1) * J + j, t * J + j)]

    edge_index = torch.tensor(edge_list, dtype=torch.long).t().contiguous()
    data = Data(x=x, edge_index=edge_index, y=torch.tensor(label, dtype=torch.long))
    # data = Data(x=x, edge_index=edge_index, y=label)
    print(f"Data object: {data}")
    # print(f"Data x shape: {data.x.shape}")
    # print(f"Data edge_index shape: {data.edge_index.shape}")
    # print(f"Data y shape: {data.y}")
    # print(f"Data num_nodes: {data.num_nodes}")
    return data

graphs = []
for sequence_tensor, label in dataset:
    # Convert TensorFlow tensor to NumPy, then to PyTorch tensor
    sequence_tensor = torch.tensor(sequence_tensor.numpy())  # Convert to PyTorch tensor
    graph = build_graph(sequence_tensor, label)
    graphs.append(graph)

test_graphs = []
for sequence_tensor, label in test_dataset:
    sequence_tensor = torch.tensor(sequence_tensor.numpy())  # Convert to PyTorch tensor
    graph = build_graph(sequence_tensor, label)
    test_graphs.append(graph)
# Out:
# Loaded dataset size: 60
# Loaded test dataset size: 12
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=0)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)
# Data object: Data(x=[1650, 4], edge_index=[2, 6534], y=1)

# %%
model = HGCN(in_channels=4, hidden_channels=64, num_classes=2)
# model = ImprovedHGCN(in_channels=4, hidden_channels=64, num_classes=2)
# Create a DataLoader for the dataset
train_loader = DataLoader(graphs, batch_size=16, shuffle=True) #batch default is 32

test_loader = DataLoader(test_graphs, batch_size=16, shuffle=False)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=0.001, weight_decay=0.01) #try sgd or adam, or adamw
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=15, gamma=0.1) 
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)
# Training loop
epochs = 50 # May need more epochs for the combined model to train
overall_acc = 0.0
overall_loss = 0.0

for epoch in range(epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    for i, batch in enumerate(train_loader):
        batch_data = batch.to(device)  # Move the entire batch to the device
        batch_labels = batch.y.to(device)  # Extract labels
        optimizer.zero_grad()
        outputs = model(batch_data)
        loss = criterion(outputs, batch_labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += batch_labels.size(0)
        correct += (predicted == batch_labels).sum().item()

        loss_per_epoch = running_loss / len(train_loader)
        epoch_acc = 100 * correct / total
        print(f"Epoch [{epoch+1}/{epochs}], Step [{i+1}/{len(train_loader)}], Loss: {loss_per_epoch:.4f}, Accuracy: {epoch_acc:.2f}%")
        
    
    model.eval()
    with torch.no_grad():
        val_loss = 0.0
        correct = 0
        total = 0
        all_preds = []
        all_labels = []
        for i, batch_test_data in enumerate(test_loader):
            batch_test_data = batch_test_data.to(device)  # Move the entire batch to the device
            batch_test_labels = batch_test_data.y.to(device)  # Extract labels
            optimizer.zero_grad()
            # Forward pass

            outputs = model(batch_test_data)
            loss = criterion(outputs, batch_test_labels)

            val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += batch_test_labels.size(0)
            correct += (predicted == batch_test_labels).sum().item()
            
            all_preds.append(predicted.cpu())
            all_labels.append(batch_test_labels.cpu())


        val_loss /= len(test_loader)
        val_acc = 100 * correct / total
        
        all_preds = torch.cat(all_preds)
        all_labels = torch.cat(all_labels)

        val_f1 = f1_score(all_labels.cpu(), all_preds.cpu(), average='weighted')

        print(f"Epoch [{epoch+1}/{epochs}], Val Loss: {val_loss:.4f}, Val Accuracy: {val_acc:.2f}%, Val F1 Score: {val_f1:.4f}")

        # Save model if it's the best so far
        if val_loss < overall_loss or val_acc > overall_acc:
            overall_acc = val_acc
            overall_loss = val_loss
            # torch.save(model.state_dict(), 'best_stgcn_reasoning_model.pth')
            print(f"Saved new best model with Val Accuracy: {overall_acc:.2f}% and F1 Score: {val_f1:.4f}")

    scheduler.step() # Step the scheduler after validation

print("Training completed.")
print(f"Best Val Accuracy achieved: {overall_acc:.2f}%")
print(f"Best Val Loss achieved: {overall_loss:.4f}")
# Out:
# Epoch [1/50], Step [1/4], Loss: 0.0069, Accuracy: 100.00%
# Epoch [1/50], Step [2/4], Loss: 0.1056, Accuracy: 93.75%
# Epoch [1/50], Step [3/4], Loss: 0.1264, Accuracy: 95.83%
# Epoch [1/50], Step [4/4], Loss: 0.1801, Accuracy: 93.33%
# Epoch [1/50], Val Loss: 0.5792, Val Accuracy: 83.33%, Val F1 Score: 0.8333
# Saved new best model with Val Accuracy: 83.33% and F1 Score: 0.8333
# Epoch [2/50], Step [1/4], Loss: 0.0156, Accuracy: 100.00%
# Epoch [2/50], Step [2/4], Loss: 0.0278, Accuracy: 100.00%
# Epoch [2/50], Step [3/4], Loss: 0.0833, Accuracy: 97.92%
# Epoch [2/50], Step [4/4], Loss: 0.0851, Accuracy: 98.33%
# Epoch [2/50], Val Loss: 0.5734, Val Accuracy: 91.67%, Val F1 Score: 0.9172
# Saved new best model with Val Accuracy: 91.67% and F1 Score: 0.9172
# Epoch [3/50], Step [1/4], Loss: 0.0046, Accuracy: 100.00%
# Epoch [3/50], Step [2/4], Loss: 0.0258, Accuracy: 100.00%
# Epoch [3/50], Step [3/4], Loss: 0.0339, Accuracy: 100.00%
# Epoch [3/50], Step [4/4], Loss: 0.0441, Accuracy: 100.00%
# Epoch [3/50], Val Loss: 0.8439, Val Accuracy: 75.00%, Val F1 Score: 0.7448
# Epoch [4/50], Step [1/4], Loss: 0.0123, Accuracy: 100.00%
# Epoch [4/50], Step [2/4], Loss: 0.0178, Accuracy: 100.00%
# Epoch [4/50], Step [3/4], Loss: 0.0484, Accuracy: 97.92%
# Epoch [4/50], Step [4/4], Loss: 0.0556, Accuracy: 98.33%
# Epoch [4/50], Val Loss: 0.7615, Val Accuracy: 83.33%, Val F1 Score: 0.8333
# Epoch [5/50], Step [1/4], Loss: 0.0118, Accuracy: 100.00%
# Epoch [5/50], Step [2/4], Loss: 0.0219, Accuracy: 100.00%
# Epoch [5/50], Step [3/4], Loss: 0.0356, Accuracy: 100.00%
# Epoch [5/50], Step [4/4], Loss: 0.0969, Accuracy: 98.33%
# Epoch [5/50], Val Loss: 0.7737, Val Accuracy: 75.00%, Val F1 Score: 0.7517
# Epoch [6/50], Step [1/4], Loss: 0.0246, Accuracy: 93.75%
# Epoch [6/50], Step [2/4], Loss: 0.0588, Accuracy: 93.75%
# Epoch [6/50], Step [3/4], Loss: 0.0697, Accuracy: 95.83%
# Epoch [6/50], Step [4/4], Loss: 0.0730, Accuracy: 96.67%
# Epoch [6/50], Val Loss: 0.4417, Val Accuracy: 83.33%, Val F1 Score: 0.8333
#
Val Accuracy: 83.33%, Val F1 Score: 0.8333
# Epoch [15/50], Step [1/4], Loss: 0.0043, Accuracy: 100.00%
# Epoch [15/50], Step [2/4], Loss: 0.0054, Accuracy: 100.00%
# Epoch [15/50], Step [3/4], Loss: 0.0103, Accuracy: 100.00%
# Epoch [15/50], Step [4/4], Loss: 0.0111, Accuracy: 100.00%
# Epoch [15/50], Val Loss: 1.5204, Val Accuracy: 83.33%, Val F1 Score: 0.8333
# Epoch [16/50], Step [1/4], Loss: 0.0031, Accuracy: 100.00%
# Epoch [16/50], Step [2/4], Loss: 0.0099, Accuracy: 100.00%
# Epoch [16/50], Step [3/4], Loss: 0.0115, Accuracy: 100.00%
# Epoch [16/50], Step [4/4], Loss: 0.0123, Accuracy: 100.00%
# Epoch [16/50], Val Loss: 1.4214, Val Accuracy: 83.33%, Val F1 Score: 0.8333
# Epoch [17/50], Step [1/4], Loss: 0.0016, Accuracy: 100.00%
# Epoch [17/50], Step [2/4], Loss: 0.0044, Accuracy: 100.00%
# Epoch [17/50], Step [3/4], Loss: 0.0119, Accuracy: 100.00%
# Epoch [17/50], Step [4/4], Loss: 0.0163, Accuracy: 100.00%
# Epoch [17/50], Val Loss: 1.0224, Val Accuracy: 83.33%, Val F1 Score: 0.8333
# Epoch [18/50], Step [1/4], Loss: 0.0010, Accuracy: 100.00%
# Epoch [18/50], Step [2/4], Loss: 0.0143, Accuracy: 100.00%
# Epoch [18/50], Step [3/4], Loss: 0.0162, Accuracy: 100.00%
# Epoch [18/50], Step [4/4], Loss: 0.0207, Accuracy: 100.00%
# Epoch [18/50], Val Loss: 0.8704, Val Accuracy: 83.33%, Val F1 Score: 0.8333
# Epoch [19/50], Step [1/4], Loss: 0.0031, Accuracy: 100.00%
# Epoch [19/50], Step [2/4], Loss: 0.0064, Accuracy: 100.00%
# Epoch [19/50], Step [3/4], Loss: 0.0071, Accuracy: 100.00%
# Epoch [19/50], Step [4/4], Loss: 0.0074, Accuracy: 100.00%
# Epoch [19/50], Val Loss: 0.9545, Val Accuracy: 83.33%, Val F1 Score: 0.8333
# Epoch [20/50], Step [1/4], Loss: 0.0013, Accuracy: 100.00%
# Epoch [20/50], Step [2/4], Loss: 0.0036, Accuracy: 100.00%
# Epoch [20/50], Step [3/4], Loss: 0.0097, Accuracy: 100.00%
# Epoch [20/50], Step [4/4], Loss: 0.0108, Accuracy: 100.00%
# Epoch [20/50], Val Loss: 1.0863, Val Accuracy: 83.33%, Val F1 Score: 0.8333
# Epoch [21/50], Step [1/4], Loss: 0.0015, Accuracy: 100.00%
# Epoch [21/50], Step [2/4], Loss: 0.0030, Accuracy: 100.00%
# Epoch [21/50], Step [3/4], Loss: 0.0035, Accuracy: 100.00%
# Epoch [21/50], Step [4/4], Loss: 0.0227, Accuracy: 100.00%
# Epoch [21/50], Val Loss: 1.3031, Val Accuracy: 83.33%, Val F1 Score: 0.8333
# Epoch [22/50], Step [1/4], Loss: 0.0028, Accuracy: 100.00%
# Epoch [22/50], Step [2/4], Loss: 0.0043, Accuracy: 100.00%
# Epoch [22/50], Step [3/4], Loss: 0.0100, Accuracy: 100.00%
# Epoch [22/50], Step [4/4], Loss: 0.0116, Accuracy: 100.00%
# Epoch [22/50], Val Loss: 1.1117, Val Accuracy: 83.33%, Val F1 Score: 0.8333
# Epoch [23/50], Step [1/4], Loss: 0.0009, Accuracy: 100.00%
# Epoch [23/50], Step [2/4], Loss: 0.0019, Accuracy: 100.00%
# Epoch [23/50], Step [3/4], Loss: 0.0055, Accuracy: 100.00%
# Epoch [23/50], Step [4/4], Loss: 0.0097, Accuracy: 100.00%
# Epoch [23/50], Val Loss: 1.1777, Val Accuracy: 83.33%, Val F1 Score: 0.8333
# Epoch
Val Accuracy: 83.33%, Val F1 Score: 0.8333
# Epoch [33/50], Step [1/4], Loss: 0.0007, Accuracy: 100.00%
# Epoch [33/50], Step [2/4], Loss: 0.0300, Accuracy: 96.88%
# Epoch [33/50], Step [3/4], Loss: 0.0366, Accuracy: 97.92%
# Epoch [33/50], Step [4/4], Loss: 0.0400, Accuracy: 98.33%
# Epoch [33/50], Val Loss: 1.0898, Val Accuracy: 83.33%, Val F1 Score: 0.8333
# Epoch [34/50], Step [1/4], Loss: 0.0022, Accuracy: 100.00%
# Epoch [34/50], Step [2/4], Loss: 0.0028, Accuracy: 100.00%
# Epoch [34/50], Step [3/4], Loss: 0.0045, Accuracy: 100.00%
# Epoch [34/50], Step [4/4], Loss: 0.0054, Accuracy: 100.00%
# Epoch [34/50], Val Loss: 1.1259, Val Accuracy: 83.33%, Val F1 Score: 0.8333
# Epoch [35/50], Step [1/4], Loss: 0.0039, Accuracy: 100.00%
# Epoch [35/50], Step [2/4], Loss: 0.0044, Accuracy: 100.00%
# Epoch [35/50], Step [3/4], Loss: 0.0066, Accuracy: 100.00%
# Epoch [35/50], Step [4/4], Loss: 0.0152, Accuracy: 100.00%
# Epoch [35/50], Val Loss: 1.0852, Val Accuracy: 83.33%, Val F1 Score: 0.8333
# Epoch [36/50], Step [1/4], Loss: 0.0003, Accuracy: 100.00%
# Epoch [36/50], Step [2/4], Loss: 0.0028, Accuracy: 100.00%
# Epoch [36/50], Step [3/4], Loss: 0.0064, Accuracy: 100.00%
# Epoch [36/50], Step [4/4], Loss: 0.0118, Accuracy: 100.00%
# Epoch [36/50], Val Loss: 1.0318, Val Accuracy: 83.33%, Val F1 Score: 0.8333
# Epoch [37/50], Step [1/4], Loss: 0.0003, Accuracy: 100.00%
# Epoch [37/50], Step [2/4], Loss: 0.0077, Accuracy: 100.00%
# Epoch [37/50], Step [3/4], Loss: 0.0111, Accuracy: 100.00%
# Epoch [37/50], Step [4/4], Loss: 0.0123, Accuracy: 100.00%
# Epoch [37/50], Val Loss: 0.9152, Val Accuracy: 83.33%, Val F1 Score: 0.8333
# Epoch [38/50], Step [1/4], Loss: 0.0027, Accuracy: 100.00%
# Epoch [38/50], Step [2/4], Loss: 0.0069, Accuracy: 100.00%
# Epoch [38/50], Step [3/4], Loss: 0.0083, Accuracy: 100.00%
# Epoch [38/50], Step [4/4], Loss: 0.0106, Accuracy: 100.00%
# Epoch [38/50], Val Loss: 0.9632, Val Accuracy: 83.33%, Val F1 Score: 0.8333
# Epoch [39/50], Step [1/4], Loss: 0.0042, Accuracy: 100.00%
# Epoch [39/50], Step [2/4], Loss: 0.0071, Accuracy: 100.00%
# Epoch [39/50], Step [3/4], Loss: 0.0082, Accuracy: 100.00%
# Epoch [39/50], Step [4/4], Loss: 0.0090, Accuracy: 100.00%
# Epoch [39/50], Val Loss: 0.8955, Val Accuracy: 83.33%, Val F1 Score: 0.8333
# Epoch [40/50], Step [1/4], Loss: 0.0007, Accuracy: 100.00%
# Epoch [40/50], Step [2/4], Loss: 0.0010, Accuracy: 100.00%
# Epoch [40/50], Step [3/4], Loss: 0.0091, Accuracy: 100.00%
# Epoch [40/50], Step [4/4], Loss: 0.0304, Accuracy: 100.00%
# Epoch [40/50], Val Loss: 1.0930, Val Accuracy: 83.33%, Val F1 Score: 0.8333
# Epoch [41/50], Step [1/4], Loss: 0.0017, Accuracy: 100.00%
# Epoch [41/50], Step [2/4], Loss: 0.0066, Accuracy: 100.00%
# Epoch [41/50], Step [3/4], Loss: 0.0069, Accuracy: 100.00%
# Epoch [41/50], Step [4/4], Loss: 0.0136, Accuracy: 100.00%
# Epoch [41/50], Val Loss: 1.2176, Val Accuracy: 83.33%, Val F1 Score: 0.8333
# Epoch [42/50], Step [1/4], Loss: 0.0055, Accuracy: 100.00%
# Epoch [42/50], Step [2/4], Loss: 0.0125, Accuracy: 100.00%
# Epoch [42/50], Step [3/4], Loss: 0.0134, Accuracy: 100.00%
# Epoch [42/50], Step [4/4], Loss: 0.0163, Accuracy: 100.00%
# Epoch [42/50], Val Loss: 1.0251, Val Accuracy: 83.33%, Val F1 Score: 0.8333
# Epoch [43/50], Step [1/4], Loss: 0.0042, Accuracy: 100.00%
# Epoch [43/50], Step [2/4], Loss: 0.0054, Accuracy: 100.00%
# Epoch [43/50], Step [3/4], Loss: 0.0058, Accuracy: 100.00%
# Epoch [43/50], Step [4/4], Loss: 0.0093, Accuracy: 100.00%
# Epoch [43/50], Val Loss: 0.9855, Val Accuracy: 83.33%, Val F1 Score: 0.8333
# Epoch [44/50], Step [1/4], Loss: 0.0025, Accuracy: 100.00%
# Epoch [44/50], Step [2/4], Loss: 0.0029, Accuracy: 100.00%
# Epoch [44/50], Step [3/4], Loss: 0.0047, Accuracy: 100.00%
# Epoch [44/50], Step [4/4], Loss: 0.0062, Accuracy: 100.00%
# Epoch [44/50], Val Loss: 0.9730, Val Accuracy: 83.33%, Val F1 Score: 0.8333
# Epoch [45/50], Step [1/4], Loss: 0.0021, Accuracy: 100.00%
# Epoch [45/50], Step [2/4], Loss: 0.0071, Accuracy: 100.00%
# Epoch [45/50], Step [3/4], Loss: 0.0079, Accuracy: 100.00%
# Epoch [45/50], Step [4/4], Loss: 0.0095, Accuracy: 100.00%
# Epoch [45/50], Val Loss: 0.8765, Val Accuracy: 83.33%, Val F1 Score: 0.8333
# Epoch [46/50], Step [1/4], Loss: 0.0014, Accuracy: 100.00%
# Epoch [46/50], Step [2/4], Loss: 0.0017, Accuracy: 100.00%
# Epoch [46/50], Step [3/4], Loss: 0.0026, Accuracy: 100.00%
# Epoch [46/50], Step [4/4], Loss: 0.0089, Accuracy: 100.00%
# Epoch [46/50], Val Loss: 0.8981, Val Accuracy: 83.33%, Val F1 Score: 0.8333
# Epoch [47/50], Step [1/4], Loss: 0.0005, Accuracy: 100.00%
# Epoch [47/50], Step [2/4], Loss: 0.0053, Accuracy: 100.00%
# Epoch [47/50], Step [3/4], Loss: 0.0057, Accuracy: 100.00%
# Epoch [47/50], Step [4/4], Loss: 0.0101, Accuracy: 100.00%
# Epoch [47/50], Val Loss: 0.8228, Val Accuracy: 83.33%, Val F1 Score: 0.8333
# Epoch [48/50], Step [1/4], Loss: 0.0005, Accuracy: 100.00%
# Epoch [48/50], Step [2/4], Loss: 0.0011, Accuracy: 100.00%
# Epoch [48/50], Step [3/4], Loss: 0.0056, Accuracy: 100.00%
# Epoch [48/50], Step [4/4], Loss: 0.0091, Accuracy: 100.00%
# Epoch [48/50], Val Loss: 1.1554, Val Accuracy: 83.33%, Val F1 Score: 0.8333
# Epoch [49/50], Step [1/4], Loss: 0.0009, Accuracy: 100.00%
# Epoch [49/50], Step [2/4], Loss: 0.0033, Accuracy: 100.00%
# Epoch [49/50], Step [3/4], Loss: 0.0153, Accuracy: 100.00%
# Epoch [49/50], Step [4/4], Loss: 0.0451, Accuracy: 98.33%
# Epoch [49/50], Val Loss: 1.1468, Val Accuracy: 83.33%, Val F1 Score: 0.8333
# Epoch [50/50], Step [1/4], Loss: 0.0011, Accuracy: 100.00%
# Epoch [50/50], Step [2/4], Loss: 0.0026, Accuracy: 100.00%
# Epoch [50/50], Step [3/4], Loss: 0.0040, Accuracy: 100.00%
# Epoch [50/50], Step [4/4], Loss: 0.0125, Accuracy: 100.00%
# Epoch [50/50], Val Loss: 1.2292, Val Accuracy: 83.33%, Val F1 Score: 0.8333
# Training completed.
# Best Val Accuracy achieved: 83.33%
# Best Val Loss achieved: 0.4417
